# %%
import black
import jupyter_black

jupyter_black.load(
    lab=True,
    line_length=110,
    target_version=black.TargetVersion.PY310,
)
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import os
import re

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

from matplotlib.colors import BoundaryNorm, ListedColormap

import lysis

pd.reset_option("display.precision")
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

# %%
compilations = {
    "Front Velocity": [
        "Mean front velocity",
        "Mean of Standard Deviation of front velocity",
    ],
    "Degradation Rate": ["Mean degradation rate", "Standard deviation of degradation rate"],
    "Mean First Passage Time": ["Mean first passage time (min)", "Standard deviation of first passage time"],
    "Macroscale Unbinds": [
        "Mean number of macroscale unbinds",
        "Standard deviation in number of macroscale unbinds",
    ],
    "Microscale Unbinds": [
        "Mean number of microscale unbinds",
        "Standard deviation in number of microscale unbinds",
    ],
}

results = {}

# %%
exp_code = "2023-01-30-2000"
e = lysis.util.Experiment(os.path.join("..", "..", "data"), experiment_code=exp_code)
e.read_file()
results[exp_code] = pd.read_json(os.path.join(e.os_path, "results.json"), orient="table")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 3
#       1 exp_code = "2023-01-30-2000"
#       2 e = lysis.util.Experiment(os.path.join("..", "..", "data"), experiment_code=exp_code)
# ----> 3 e.read_file()
#       4 results[exp_code] = pd.read_json(os.path.join(e.os_path, "results.json"), orient="table")
#
# File ~/git/UCO-OpResearch/lysis/src/python/lysis/util/parameters.py:185, in Experiment.read_file(self)
#     183 # Determine whether the parameter file exists for this experiment
#     184 if not os.path.isfile(self.os_param_file):
# --> 185     raise RuntimeError("Experiment parameter file not found.")
#     186 # Open the file
#     187 with open(self.os_param_file, "r") as file:
#     188     # Use the JSON library to read in the parameters as a dictionary
#
# RuntimeError: Experiment parameter file not found.

# %%
which_display = "Front Velocity"
display = pd.DataFrame(index=results[exp_code].index)
display = results[exp_code][compilations[which_display]].apply(
    lambda x: f"{x[0]:.2f} \u00B1 {x[1]:.2f}", axis=1
)
display.unstack(0).reindex(results[exp_code].index.get_level_values(1).unique())[
    results[exp_code].index.get_level_values(0).unique()
]
# Out:
# data                                 Physiological Kd    10x bigger  \
# program
# Always bind                               6.80 ± 0.05  10.64 ± 0.16
# Diffuse along clot                        4.35 ± 0.04   9.44 ± 0.15
# Diffuse into clot                        10.93 ± 1.78  15.43 ± 0.60
# Diffuse into and along clot - BUGGED     10.93 ± 1.76  15.46 ± 0.62
# Diffuse into and along clot - FIXED       6.23 ± 0.26  10.11 ± 0.18
#
# data                                  10x smaller
# program
# Always bind                           6.23 ± 0.04
# Diffuse along clot                    1.55 ± 0.06
# Diffuse into clot                     2.98 ± 0.75
# Diffuse into and along clot - BUGGED  3.00 ± 0.73
# Diffuse into and along clot - FIXED   2.22 ± 0.10

# %%
results[exp_code]
# Out:
#                                                       Mean front velocity  \
# data             program
# Physiological Kd Always bind                                         6.80
#                  Diffuse along clot                                  4.35
#                  Diffuse into clot                                  10.93
#                  Diffuse into and along clot - BUGGED               10.93
#                  Diffuse into and along clot - FIXED                 6.23
# 10x bigger       Always bind                                        10.64
#                  Diffuse along clot                                  9.44
#                  Diffuse into clot                                  15.43
#                  Diffuse into and along clot - BUGGED               15.46
#                  Diffuse into and along clot - FIXED                10.11
# 10x smaller      Always bind                                         6.23
#                  Diffuse along clot                                  1.55
#                  Diffuse into clot                                   2.98
#                  Diffuse into and along clot - BUGGED                3.00
#                  Diffuse into and along clot - FIXED                 2.22
#
#                                                       Mean of Standard Deviation of front velocity  \
# data             program
# Physiological Kd Always bind                                                                  0.05
#                  Diffuse along clot                                                           0.04
#                  Diffuse into clot                                                            1.78
#                  Diffuse into and along clot - BUGGED                                         1.76
#                  Diffuse into and along clot - FIXED                                          0.26
# 10x bigger       Always bind                                                                  0.16
#                  Diffuse along clot                                                           0.15
#                  Diffuse into clot                                                            0.60
#                  Diffuse into and along clot - BUGGED                                         0.62
#                  Diffuse into and along clot - FIXED                                          0.18
# 10x smaller      Always bind                                                                  0.04
#                  Diffuse along clot                                                           0.06
#                  Diffuse into clot                                                            0.75
#                  Diffuse into and along clot - BUGGED                                         0.73
#                  Diffuse into and along clot - FIXED                                          0.10
#
#                                                        Mean degradation percent  \
# data             program
# Physiological Kd Always bind                                             100.00
#                  Diffuse along clot                                       85.92
#                  Diffuse into clot                                       100.00
#                  Diffuse into and along clot - BUGGED                    100.00
#                  Diffuse into and along clot - FIXED                     100.00
# 10x bigger       Always bind                                             100.00
#                  Diffuse along clot                                      100.00
#                  Diffuse into clot                                       100.00
#                  Diffuse into and along clot - BUGGED                    100.00
#                  Diffuse into and along clot - FIXED                     100.00
# 10x smaller      Always bind                                             100.00
#                  Diffuse along clot                                       31.92
#                  Diffuse into clot                                       100.00
#                  Diffuse into and along clot - BUGGED                    100.00
#                  Diffuse into and along clot - FIXED                      93.57
#
#                                                        Mean degradation rate  \
# data             program
# Physiological Kd Always bind                                            6.75
#                  Diffuse along clot                                     4.34
#                  Diffuse into clot                                     17.97
#                  Diffuse into and along clot - BUGGED                  18.01
#                  Diffuse into and along clot - FIXED                    7.93
# 10x bigger       Always bind                                           10.57
#                  Diffuse along clot                                     9.40
#                  Diffuse into clot                                     16.12
#                  Diffuse into and along clot - BUGGED                  16.09
#                  Diffuse into and along clot - FIXED                   10.14
# 10x smaller      Always bind                                            6.19
#                  Diffuse along clot                                     1.53
#                  Diffuse into clot                                      7.38
#                  Diffuse into and along clot - BUGGED                   7.38
#                  Diffuse into and along clot - FIXED                    3.35
#
#                                                        Standard deviation of degradation rate  \
# data             program
# Physiological Kd Always bind                                                             0.01
#                  Diffuse along clot                                                      0.01
#                  Diffuse into clot                                                       0.16
#                  Diffuse into and along clot - BUGGED                                    0.18
#                  Diffuse into and along clot - FIXED                                     0.07
# 10x bigger       Always bind                                                             0.01
#                  Diffuse along clot                                                      0.02
#                  Diffuse into clot                                                       0.03
#                  Diffuse into and along clot - BUGGED                                    0.08
#                  Diffuse into and along clot - FIXED                                     0.04
# 10x smaller      Always bind                                                             0.02
#                  Diffuse along clot                                                      0.01
#                  Diffuse into clot                                                       0.04
#                  Diffuse into and along clot - BUGGED                                    0.05
#                  Diffuse into and along clot - FIXED                                     0.03
#
#                                                        Number of molecules that reached the back row  \
# data             program
# Physiological Kd Always bind                                                                   43068
#                  Diffuse along clot                                                                2
#                  Diffuse into clot                                                             43066
#                  Diffuse into and along clot - BUGGED                                          43066
#                  Diffuse into and along clot - FIXED                                           43065
# 10x bigger       Always bind                                                                   42400
#                  Diffuse along clot                                                            42930
#                  Diffuse into clot                                                             43060
#                  Diffuse into and along clot - BUGGED                                          43053
#                  Diffuse into and along clot - FIXED                                           43073
# 10x smaller      Always bind                                                                   43066
#                  Diffuse along clot                                                                0
#                  Diffuse into clot                                                             43056
#                  Diffuse into and along clot - BUGGED                                          43060
#                  Diffuse into and along clot - FIXED                                           28793
#
#                                                        Percent of molecules that reached the back row  \
# data             program
# Physiological Kd Always bind                                                                    99.99
#                  Diffuse along clot                                                              0.00
#                  Diffuse into clot                                                              99.98
#                  Diffuse into and along clot - BUGGED                                           99.98
#                  Diffuse into and along clot - FIXED                                            99.98
# 10x bigger       Always bind                                                                    98.44
#                  Diffuse along clot                                                             99.67
#                  Diffuse into clot                                                              99.97
#                  Diffuse into and along clot - BUGGED                                           99.95
#                  Diffuse into and along clot - FIXED                                           100.00
# 10x smaller      Always bind                                                                    99.98
#                  Diffuse along clot                                                              0.00
#                  Diffuse into clot                                                              99.96
#                  Diffuse into and along clot - BUGGED                                           99.97
#                  Diffuse into and along clot - FIXED                                            66.85
#
#                                                        Mean first passage time (min)  \
# data             program
# Physiological Kd Always bind                                                   15.11
#                  Diffuse along clot                                            19.49
#                  Diffuse into clot                                              5.00
#                  Diffuse into and along clot - BUGGED                           4.99
#                  Diffuse into and along clot - FIXED                           12.72
# 10x bigger       Always bind                                                    9.75
#                  Diffuse along clot                                            11.24
#                  Diffuse into clot                                              6.68
#                  Diffuse into and along clot - BUGGED                           6.73
#                  Diffuse into and along clot - FIXED                           10.56
# 10x smaller      Always bind                                                   16.38
#                  Diffuse along clot                                              NaN
#                  Diffuse into clot                                              3.07
#                  Diffuse into and along clot - BUGGED                           3.05
#                  Diffuse into and along clot - FIXED                           19.47
#
#                                                        Standard deviation of first passage time  \
# data             program
# Physiological Kd Always bind                                                               1.15
#                  Diffuse along clot                                                        0.25
#                  Diffuse into clot                                                         2.69
#                  Diffuse into and along clot - BUGGED                                      2.67
#                  Diffuse into and along clot - FIXED                                       3.49
# 10x bigger       Always bind                                                               1.04
#                  Diffuse along clot                                                        1.62
#                  Diffuse into clot                                                         1.70
#                  Diffuse into and along clot - BUGGED                                      1.72
#                  Diffuse into and along clot - FIXED                                       1.83
# 10x smaller      Always bind                                                               1.11
#                  Diffuse along clot                                                         NaN
#                  Diffuse into clot                                                         2.49
#                  Diffuse into and along clot - BUGGED                                      2.49
#                  Diffuse into and along clot - FIXED                                       9.81
#
#                                                        Mean number of macroscale unbinds  \
# data             program
# Physiological Kd Always bind                                                         NaN
#                  Diffuse along clot                                           594,867.50
#                  Diffuse into clot                                            205,717.10
#                  Diffuse into and along clot - BUGGED                         205,944.10
#                  Diffuse into and along clot - FIXED                          434,408.90
# 10x bigger       Always bind                                                         NaN
#                  Diffuse along clot                                           571,004.10
#                  Diffuse into clot                                            369,550.00
#                  Diffuse into and along clot - BUGGED                         369,901.00
#                  Diffuse into and along clot - FIXED                          533,335.00
# 10x smaller      Always bind                                                         NaN
#                  Diffuse along clot                                           154,365.30
#                  Diffuse into clot                                            108,361.40
#                  Diffuse into and along clot - BUGGED                         108,462.60
#                  Diffuse into and along clot - FIXED                          213,134.20
#
#                                                        Standard deviation in number of macroscale unbinds  \
# data             program
# Physiological Kd Always bind                                                                         NaN
#                  Diffuse along clot                                                               608.71
#                  Diffuse into clot                                                                727.29
#                  Diffuse into and along clot - BUGGED                                             722.66
#                  Diffuse into and along clot - FIXED                                            2,741.68
# 10x bigger       Always bind                                                                         NaN
#                  Diffuse along clot                                                             1,204.67
#                  Diffuse into clot                                                                562.57
#                  Diffuse into and along clot - BUGGED                                             657.76
#                  Diffuse into and along clot - FIXED                                            1,322.27
# 10x smaller      Always bind                                                                         NaN
#                  Diffuse along clot                                                               169.41
#                  Diffuse into clot                                                                404.93
#                  Diffuse into and along clot - BUGGED                                             414.49
#                  Diffuse into and along clot - FIXED                                              289.18
#
#                                                        Mean number of microscale unbinds  \
# data             program
# Physiological Kd Always bind                                                         NaN
#                  Diffuse along clot                                            48,267.60
#                  Diffuse into clot                                             30,342.50
#                  Diffuse into and along clot - BUGGED                          30,390.20
#                  Diffuse into and along clot - FIXED                           40,807.40
# 10x bigger       Always bind                                                         NaN
#                  Diffuse along clot                                            29,781.20
#                  Diffuse into clot                                             22,862.30
#                  Diffuse into and along clot - BUGGED                          22,815.80
#                  Diffuse into and along clot - FIXED                           28,150.10
# 10x smaller      Always bind                                                         NaN
#                  Diffuse along clot                                            16,174.20
#                  Diffuse into clot                                             28,893.30
#                  Diffuse into and along clot - BUGGED                          28,759.70
#                  Diffuse into and along clot - FIXED                           33,028.80
#
#                                                        Standard deviation in number of microscale unbinds
# data             program
# Physiological Kd Always bind                                                                         NaN
#                  Diffuse along clot                                                               273.64
#                  Diffuse into clot                                                                161.28
#                  Diffuse into and along clot - BUGGED                                             175.36
#                  Diffuse into and along clot - FIXED                                              111.22
# 10x bigger       Always bind                                                                         NaN
#                  Diffuse along clot                                                                66.56
#                  Diffuse into clot                                                                135.25
#                  Diffuse into and along clot - BUGGED                                              77.69
#                  Diffuse into and along clot - FIXED                                              253.08
# 10x smaller      Always bind                                                                         NaN
#                  Diffuse along clot                                                               130.97
#                  Diffuse into clot                                                                226.08
#                  Diffuse into and along clot - BUGGED                                             150.20
#                  Diffuse into and along clot - FIXED                                              238.72

# %%
which_display = "Mean First Passage Time"
display = pd.DataFrame(index=results[exp_code].index)
display = results[exp_code][compilations[which_display]].apply(
    lambda x: f"{x[0]:.2f} \u00B1 {x[1]:.2f}", axis=1
)
display.unstack(0).reindex(results[exp_code].index.get_level_values(1).unique())[
    results[exp_code].index.get_level_values(0).unique()
]
# Out:
# data                                 Physiological Kd    10x bigger  \
# program
# Always bind                              15.11 ± 1.15   9.75 ± 1.04
# Diffuse along clot                       19.49 ± 0.25  11.24 ± 1.62
# Diffuse into clot                         5.00 ± 2.69   6.68 ± 1.70
# Diffuse into and along clot - BUGGED      4.99 ± 2.67   6.73 ± 1.72
# Diffuse into and along clot - FIXED      12.72 ± 3.49  10.56 ± 1.83
#
# data                                   10x smaller
# program
# Always bind                           16.38 ± 1.11
# Diffuse along clot                       nan ± nan
# Diffuse into clot                      3.07 ± 2.49
# Diffuse into and along clot - BUGGED   3.05 ± 2.49
# Diffuse into and along clot - FIXED   19.47 ± 9.81
