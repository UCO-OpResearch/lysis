# %%
import black
import jupyter_black

jupyter_black.load(
    lab=True,
    line_length=110,
    target_version=black.TargetVersion.PY310,
)
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import os
import re

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

from matplotlib.colors import BoundaryNorm, ListedColormap

import lysis

pd.reset_option("display.precision")
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

# %%
compilations = {
    "Front Velocity": [
        "Mean front velocity",
        "Mean of Standard Deviation of front velocity",
    ],
    "Degradation Rate": ["Mean degradation rate", "Standard deviation of degradation rate"],
    "Degradation Start Time": ["Mean degradation start time", "Standard deviation of degradation start time"],
    "Mean First Passage Time": ["Mean first passage time (min)", "Standard deviation of first passage time"],
    "Macroscale Unbinds": [
        "Mean number of macroscale unbinds",
        "Standard deviation in number of macroscale unbinds",
    ],
    "Microscale Unbinds": [
        "Mean number of microscale unbinds",
        "Standard deviation in number of microscale unbinds",
    ],
}

results = {}

# %%
exp_code = "2023-02-02-2200"
e = lysis.util.Experiment(os.path.join("..", "..", "data"), experiment_code=exp_code)
e.read_file()
results[exp_code] = pd.read_json(os.path.join(e.os_path, "results.json"), orient="table")

# %%
which_display = "Macroscale Unbinds"
display = pd.DataFrame(index=results[exp_code].index)
display = results[exp_code][compilations[which_display]].apply(
    #    lambda x: f"{x[0]:.2f} \u00B1 {x[1]:.2f}", axis=1
    lambda x: f"{x[0]:,.0f} \u00B1 {x[1]:,.0f}",
    axis=1,
)
display.unstack(0).reindex(results[exp_code].index.get_level_values(1).unique())[
    results[exp_code].index.get_level_values(0).unique()
]
# Out:
# data                        Physiological Kd       10x bigger      10x smaller
# program
# Always bind                        nan ± nan        nan ± nan        nan ± nan
# Diffuse along clot           678,033 ± 1,022  571,187 ± 1,077  365,964 ± 1,026
# Diffuse into clot              206,027 ± 803    369,515 ± 583    107,985 ± 528
# Diffuse into and along clot  434,868 ± 2,193    532,955 ± 725  239,593 ± 1,924

# %%
results[exp_code]
# Out:
#                                              Mean front velocity  \
# data             program
# Physiological Kd Always bind                                6.78
#                  Diffuse along clot                         4.29
#                  Diffuse into clot                         11.00
#                  Diffuse into and along clot                6.25
# 10x bigger       Always bind                               10.62
#                  Diffuse along clot                         9.45
#                  Diffuse into clot                         15.39
#                  Diffuse into and along clot               10.10
# 10x smaller      Always bind                                6.25
#                  Diffuse along clot                         1.95
#                  Diffuse into clot                          3.07
#                  Diffuse into and along clot                2.47
#
#                                              Mean of Standard Deviation of front velocity  \
# data             program
# Physiological Kd Always bind                                                         0.05
#                  Diffuse along clot                                                  0.03
#                  Diffuse into clot                                                   1.80
#                  Diffuse into and along clot                                         0.26
# 10x bigger       Always bind                                                         0.16
#                  Diffuse along clot                                                  0.15
#                  Diffuse into clot                                                   0.59
#                  Diffuse into and along clot                                         0.18
# 10x smaller      Always bind                                                         0.04
#                  Diffuse along clot                                                  0.02
#                  Diffuse into clot                                                   0.74
#                  Diffuse into and along clot                                         0.12
#
#                                               Mean degradation percent  \
# data             program
# Physiological Kd Always bind                                    100.00
#                  Diffuse along clot                             100.00
#                  Diffuse into clot                              100.00
#                  Diffuse into and along clot                    100.00
# 10x bigger       Always bind                                    100.00
#                  Diffuse along clot                             100.00
#                  Diffuse into clot                              100.00
#                  Diffuse into and along clot                    100.00
# 10x smaller      Always bind                                    100.00
#                  Diffuse along clot                             100.00
#                  Diffuse into clot                              100.00
#                  Diffuse into and along clot                    100.00
#
#                                               Mean degradation rate  \
# data             program
# Physiological Kd Always bind                                   6.75
#                  Diffuse along clot                            4.24
#                  Diffuse into clot                            17.94
#                  Diffuse into and along clot                   7.91
# 10x bigger       Always bind                                  10.57
#                  Diffuse along clot                            9.42
#                  Diffuse into clot                            16.07
#                  Diffuse into and along clot                  10.16
# 10x smaller      Always bind                                   6.19
#                  Diffuse along clot                            1.95
#                  Diffuse into clot                             7.37
#                  Diffuse into and along clot                   3.31
#
#                                               Standard deviation of degradation rate  \
# data             program
# Physiological Kd Always bind                                                    0.01
#                  Diffuse along clot                                             0.01
#                  Diffuse into clot                                              0.14
#                  Diffuse into and along clot                                    0.05
# 10x bigger       Always bind                                                    0.02
#                  Diffuse along clot                                             0.02
#                  Diffuse into clot                                              0.13
#                  Diffuse into and along clot                                    0.03
# 10x smaller      Always bind                                                    0.01
#                  Diffuse along clot                                             0.01
#                  Diffuse into clot                                              0.03
#                  Diffuse into and along clot                                    0.03
#
#                                               Mean degradation start time  \
# data             program
# Physiological Kd Always bind                                         0.33
#                  Diffuse along clot                                  0.33
#                  Diffuse into clot                                   0.33
#                  Diffuse into and along clot                         0.33
# 10x bigger       Always bind                                         0.50
#                  Diffuse along clot                                  0.50
#                  Diffuse into clot                                   0.50
#                  Diffuse into and along clot                         0.50
# 10x smaller      Always bind                                         0.33
#                  Diffuse along clot                                  0.33
#                  Diffuse into clot                                   0.33
#                  Diffuse into and along clot                         0.33
#
#                                               Standard deviation of degradation start time  \
# data             program
# Physiological Kd Always bind                                                          0.00
#                  Diffuse along clot                                                   0.00
#                  Diffuse into clot                                                    0.00
#                  Diffuse into and along clot                                          0.00
# 10x bigger       Always bind                                                          0.00
#                  Diffuse along clot                                                   0.00
#                  Diffuse into clot                                                    0.00
#                  Diffuse into and along clot                                          0.00
# 10x smaller      Always bind                                                          0.00
#                  Diffuse along clot                                                   0.00
#                  Diffuse into clot                                                    0.00
#                  Diffuse into and along clot                                          0.00
#
#                                               Number of molecules that reached the back row  \
# data             program
# Physiological Kd Always bind                                                          41011
#                  Diffuse along clot                                                   41016
#                  Diffuse into clot                                                    40999
#                  Diffuse into and along clot                                          41016
# 10x bigger       Always bind                                                          40986
#                  Diffuse along clot                                                   41001
#                  Diffuse into clot                                                    41029
#                  Diffuse into and along clot                                          41009
# 10x smaller      Always bind                                                          41029
#                  Diffuse along clot                                                   41003
#                  Diffuse into clot                                                    43012
#                  Diffuse into and along clot                                          41018
#
#                                               Percent of molecules that reached the back row  \
# data             program
# Physiological Kd Always bind                                                           95.21
#                  Diffuse along clot                                                    95.22
#                  Diffuse into clot                                                     95.18
#                  Diffuse into and along clot                                           95.22
# 10x bigger       Always bind                                                           95.15
#                  Diffuse along clot                                                    95.19
#                  Diffuse into clot                                                     95.25
#                  Diffuse into and along clot                                           95.21
# 10x smaller      Always bind                                                           95.25
#                  Diffuse along clot                                                    95.19
#                  Diffuse into clot                                                     99.86
#                  Diffuse into and along clot                                           95.23
#
#                                               Mean first passage time (min)  \
# data             program
# Physiological Kd Always bind                                          14.90
#                  Diffuse along clot                                   24.07
#                  Diffuse into clot                                     4.64
#                  Diffuse into and along clot                          12.34
# 10x bigger       Always bind                                           9.61
#                  Diffuse along clot                                   11.03
#                  Diffuse into clot                                     6.45
#                  Diffuse into and along clot                          10.27
# 10x smaller      Always bind                                          16.22
#                  Diffuse along clot                                   52.92
#                  Diffuse into clot                                     3.04
#                  Diffuse into and along clot                          23.27
#
#                                               Standard deviation of first passage time  \
# data             program
# Physiological Kd Always bind                                                      0.52
#                  Diffuse along clot                                               1.32
#                  Diffuse into clot                                                2.23
#                  Diffuse into and along clot                                      3.21
# 10x bigger       Always bind                                                      0.76
#                  Diffuse along clot                                               1.17
#                  Diffuse into clot                                                1.19
#                  Diffuse into and along clot                                      1.26
# 10x smaller      Always bind                                                      0.48
#                  Diffuse along clot                                               1.45
#                  Diffuse into clot                                                2.43
#                  Diffuse into and along clot                                     10.09
#
#                                               Mean number of macroscale unbinds  \
# data             program
# Physiological Kd Always bind                                                NaN
#                  Diffuse along clot                                  678,033.10
#                  Diffuse into clot                                   206,026.70
#                  Diffuse into and along clot                         434,868.50
# 10x bigger       Always bind                                                NaN
#                  Diffuse along clot                                  571,186.70
#                  Diffuse into clot                                   369,515.30
#                  Diffuse into and along clot                         532,954.70
# 10x smaller      Always bind                                                NaN
#                  Diffuse along clot                                  365,964.30
#                  Diffuse into clot                                   107,984.80
#                  Diffuse into and along clot                         239,592.60
#
#                                               Standard deviation in number of macroscale unbinds  \
# data             program
# Physiological Kd Always bind                                                                NaN
#                  Diffuse along clot                                                    1,022.38
#                  Diffuse into clot                                                       803.01
#                  Diffuse into and along clot                                           2,193.01
# 10x bigger       Always bind                                                                NaN
#                  Diffuse along clot                                                    1,077.20
#                  Diffuse into clot                                                       582.58
#                  Diffuse into and along clot                                             724.56
# 10x smaller      Always bind                                                                NaN
#                  Diffuse along clot                                                    1,025.52
#                  Diffuse into clot                                                       528.28
#                  Diffuse into and along clot                                           1,923.70
#
#                                               Mean number of microscale unbinds  \
# data             program
# Physiological Kd Always bind                                                NaN
#                  Diffuse along clot                                   54,698.30
#                  Diffuse into clot                                    30,523.20
#                  Diffuse into and along clot                          40,968.00
# 10x bigger       Always bind                                                NaN
#                  Diffuse along clot                                   29,824.80
#                  Diffuse into clot                                    22,928.10
#                  Diffuse into and along clot                          28,149.90
# 10x smaller      Always bind                                                NaN
#                  Diffuse along clot                                   43,483.40
#                  Diffuse into clot                                    28,778.50
#                  Diffuse into and along clot                          35,458.90
#
#                                               Standard deviation in number of microscale unbinds
# data             program
# Physiological Kd Always bind                                                                NaN
#                  Diffuse along clot                                                      237.71
#                  Diffuse into clot                                                       257.65
#                  Diffuse into and along clot                                             131.22
# 10x bigger       Always bind                                                                NaN
#                  Diffuse along clot                                                      138.17
#                  Diffuse into clot                                                       198.34
#                  Diffuse into and along clot                                             152.21
# 10x smaller      Always bind                                                                NaN
#                  Diffuse along clot                                                      227.07
#                  Diffuse into clot                                                       161.00
#                  Diffuse into and along clot                                             194.43

# %%
which_display = "Microscale Unbinds"
display = pd.DataFrame(index=results[exp_code].index)
display = results[exp_code][compilations[which_display]].apply(
    # lambda x: f"{x[0]:.2f} \u00B1 {x[1]:.2f}"
    lambda x: f"{x[0]:,.0f} \u00B1 {x[1]:,.0f}",
    axis=1,
)
display = display.unstack(0).reindex(results[exp_code].index.get_level_values(1).unique())[
    results[exp_code].index.get_level_values(0).unique()
]
print(display.style.to_latex())
# Out:
# \begin{tabular}{llll}
# data & Physiological Kd & 10x bigger & 10x smaller \\
# program &  &  &  \\
# Always bind & nan ± nan & nan ± nan & nan ± nan \\
# Diffuse along clot & 54,698 ± 238 & 29,825 ± 138 & 43,483 ± 227 \\
# Diffuse into clot & 30,523 ± 258 & 22,928 ± 198 & 28,778 ± 161 \\
# Diffuse into and along clot & 40,968 ± 131 & 28,150 ± 152 & 35,459 ± 194 \\
# \end{tabular}
