# %% [markdown]
# # Runs for Micro-wrapper development

# %%
import black
import jupyter_black

jupyter_black.load(
    # lab=True,
    line_length=110,
    target_version=black.TargetVersion.PY311,
)

# %%
import os
import subprocess
import sys

sys.path.insert(1, os.path.abspath(".."))

import GooseSLURM as gs
import numpy as np

from pint import Quantity

import lysis
from lysis.util import Q_

# %%
#############################################
#### TODO: Change all this to dataframes that read from CSV
#############################################

scenario_type = np.dtype(
    [
        ("descriptor", np.str_, 40),
        ("total_molecules", int),
        ("pore_size", Quantity),  # in microns. Code requires cm
        (
            "fiber_diameter",
            Quantity,
        ),  # in nanometers. Needs to be added to pore_size to get grid_node_distance
        # ("binding_sites", Quantity),
        ("cols", int),
        ("rows", int),
        ("empty_rows", int),
        ("forced_unbind", float),
        # ("average_bound_time", Quantity),
        ("nodes", int),
        ("diss_const_tPA_wPLG", Quantity),
        ("diss_const_tPA_woPLG", Quantity),
    ]
)
mechanism_type = np.dtype(
    [("descriptor", np.str_, 40), ("micro_executable", np.str_, 40), ("macro_executable", np.str_, 40)]
)
run_type = np.dtype(
    [
        ("run_code", np.str_, 15),
        ("source_run", np.str_, 15),
        ("scenario", np.str_, 40),
        ("mechanism", np.str_, 40),
        ("micro_seed", np.int64),
        ("macro_seed", np.int64),
    ]
)
lysis_root = os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis")

# %%
scenarios = np.array(
    [
        (
            "0.1-PKd",
            43_074,
            Q_("1.0135 um"),
            Q_("72.7 nm"),
            # Q_("427 uM"),
            93,
            121,
            28,
            0.5143,
            # Q_("277.8 sec"),
            7,
            Q_("0.002 uM"),
            Q_("0.036 uM"),
        ),
        (
            "1-PKd",
            43_074,
            Q_("1.0135 um"),
            Q_("72.7 nm"),
            # Q_("427 uM"),
            93,
            121,
            28,
            8.52e-2,
            # Q_("27.8 sec"),
            7,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "10-PKd",
            43_074,
            Q_("1.0135 um"),
            Q_("72.7 nm"),
            # Q_("427 uM"),
            93,
            121,
            28,
            5.4e-3,
            # Q_("2.78 sec"),
            7,
            Q_("0.2 uM"),
            Q_("3.6 uM"),
        ),
        (
            "TN-L__9_350",
            9_350,
            Q_("1.0135 um"),
            Q_("72.7 nm"),
            # Q_("427 uM"),
            93,
            93,
            0,
            0.0852,
            # Q_("27.8 sec"),
            7,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TN-D__9_350",
            9_350,
            Q_("0.22 um"),
            Q_("72.7 nm"),
            # Q_("427 uM"),
            342,
            116,
            0,
            0.0852,
            # Q_("27.8 sec"),
            7,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TK-L__9_350",
            9_350,
            Q_("1.0135 um"),
            Q_("145.4 nm"),
            # Q_("213 uM"),
            87,
            29,
            0,
            0.0729129,
            # Q_("27.8 sec"),
            13,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TK-D__9_350",
            9_350,
            Q_("0.22 um"),
            Q_("145.4 nm"),
            # Q_("213 uM"),
            274,
            42,
            0,
            0.0729129,
            # Q_("27.8 sec"),
            13,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TB-xi__21_105",
            21_105,
            Q_("5.34 um"),
            Q_("123 nm"),
            # Q_("248.531 uM"),
            19,
            184,
            83,
            0.077725,
            # Q_("27.8 sec"),
            11,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TF-x__9_951",
            9_951,
            Q_("2.5 um"),
            Q_("105.1 nm"),
            # Q_("306.357 uM"),
            39,
            385,
            326,
            0.078644,
            # Q_("27.8 sec"),
            10,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TF-vii__9_951",
            9_951,
            Q_("2.5 um"),
            Q_("105.1 nm"),
            # Q_("204.238 uM"),
            39,
            385,
            265,
            0.086698,
            # Q_("27.8 sec"),
            7,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TF-v__9_951",
            9_951,
            Q_("2.5 um"),
            Q_("105.1 nm"),
            # Q_("136.159 uM"),
            39,
            385,
            151,
            0.084703,
            # Q_("27.8 sec"),
            5,
            Q_("0.02 uM"),
            Q_("0.36 uM"),
        ),
        (
            "TB-xiii__21_105",
            21_105,
            Q_("5.34 microns"),
            Q_("123 nanometers"),
            19,
            184,
            112,
            0.074101,
            # Q_("27.8 sec"),
            13,
            Q_("0.02 micromolar"),
            Q_("0.36 micromolar"),
        ),
    ],
    dtype=scenario_type,
)
mechanisms = np.array(
    [
        ("Into and along - External", "micro_rates", "macro_diffuse_into_and_along__external"),
        ("Into and along - Internal", "micro_rates", "macro_diffuse_into_and_along__internal"),
    ],
    dtype=mechanism_type,
)

# %%
in_file_code = "_PLG2_tPA01_TB-xiii"
out_file_code = "__new_edgegrid"

# %%
group_code = "2024-09-02-14"
runs = np.array(
    [
        # (
        #     group_code + "00",
        #     "2023-02-02-2203",
        #     "1-PKd",
        #     "Into and along - External",
        #     981_681_759,
        #     -2_137_354_075,
        # ),
        # (
        #     group_code + "01",
        #     "2023-02-02-2208",
        #     "0.1-PKd",
        #     "Into and along - External",
        #     221_452_692,
        #     -854_989_241,
        # ),
        # (
        #     group_code + "02",
        #     "2023-02-02-2213",
        #     "10-PKd",
        #     "Into and along - External",
        #     -1_986_027_869,
        #     -1_212_172_957,
        # ),
        # (
        #     group_code + "03",
        #     "2023-12-10-1900",
        #     "TN-L__9_350",
        #     "Into and along - Internal",
        #     981_681_759,
        #     1_034_836_197,
        # ),
        # (
        #     group_code + "04",
        #     "2023-12-10-1903",
        #     "TN-D__9_350",
        #     "Into and along - Internal",
        #     981_681_759,
        #     129_314_213,
        # ),
        # (
        #     group_code + "05",
        #     "2023-12-10-1906",
        #     "TK-L__9_350",
        #     "Into and along - Internal",
        #     -34_041_038,
        #     2_608_028_918,
        # ),
        # (
        #     group_code + "06",
        #     "2023-12-10-1909",
        #     "TK-D__9_350",
        #     "Into and along - Internal",
        #     -34_041_038,
        #     106_672_317,
        # ),
        # (
        #     group_code + "07",
        #     "2024-04-16-1912",
        #     "TB-xi__21_105",
        #     "Into and along - External",
        #     1_093_845_299,
        #     2_061_649_767,
        # ),
        # (
        #     group_code + "08",
        #     "2024-04-16-1913",
        #     "TF-x__9_951",
        #     "Into and along - External",
        #     -85_552_210,
        #     3_687_972_975,
        # ),
        # (
        #     group_code + "09",
        #     "2024-04-16-1914",
        #     "TF-vii__9_951",
        #     "Into and along - External",
        #     -398_618_820,
        #     1_422_833_478,
        # ),
        # (
        #     group_code + "10",
        #     "2024-04-16-1915",
        #     "TF-v__9_951",
        #     "Into and along - External",
        #     -150_168_862,
        #     77_748_149,
        # ),
        (
            group_code + "11",
            "2024-04-16-1923",
            "TB-xiii__21_105",
            "Into and along - External",
            2_133_256_963,
            3_134_955_532,
        )
    ],
    dtype=run_type,
)

# %%
for run in runs:
    print(f"{run['run_code']}: {run['scenario']} -- {run['mechanism']}")
    mech = mechanisms[mechanisms["descriptor"] == run["mechanism"]][0]
    scen = scenarios[scenarios["descriptor"] == run["scenario"]][0]
    r = lysis.util.Run(
        os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis", "data"),
        run_code=run["run_code"],
    )
    micro_param = {
        "fiber_radius": scen["fiber_diameter"] / 2,
        "nodes_in_micro_row": int(scen["nodes"]),
        "diss_const_tPA_wPLG": scen["diss_const_tPA_wPLG"],
        "diss_const_tPA_woPLG": scen["diss_const_tPA_woPLG"],
        "micro_seed": int(run["micro_seed"]),
        "micro_version": mech["micro_executable"],
    }
    r.initialize_micro_param(micro_param)
    macro_param = {
        "total_molecules": int(scen["total_molecules"]),
        "pore_size": scen["pore_size"],
        "cols": int(scen["cols"]),
        "rows": int(scen["rows"]),
        "empty_rows": int(scen["empty_rows"]),
        "forced_unbind": scen["forced_unbind"],
        # "average_bound_time": scen["average_bound_time"],
        "macro_seed": int(run["macro_seed"]),
        "macro_version": mech["macro_executable"],
        "total_time": Q_("0 min"),
    }
    r.initialize_macro_param(macro_param)
    r.to_file()

    with open(os.path.join(r.os_path, "README.md"), "w") as file:
        file.write(
            f""" ## {r.run_code}
Micro Wrapper + HDF5 Testing
Array version

Uses Fortran Microscale code.

Uses Fortran Macroscale code with
    -  Diffuse into and along
    -  'restricted move' bug correction
    -  'passerby molecule' bug correction
    -  addition of extra output data
    -  changing the termination criteria from 'fixed time' to 'all fibers degraded'
    -  changing macro-unbind wait time to remaining leaving time.
    -  eliminating unused data variables
    -  Moved degraded fiber check into molecule loop
    -  Removed "degrade" array and use "t_degrade" instead
    -  Read in "neighborc" array generated in Python
    -  Output molecule bind/unbind times for transit time calculations
    -  Output molecule bind/unbind locations.

This set of data is comparable to "{run['scenario']}" from experiment "{run['source_run']}".
"""
        )

    result = subprocess.run(
        ["cp", os.path.join("src", "fortran", mech["micro_executable"] + ".f90"), r.os_path],
        cwd=os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis"),
        capture_output=True,
    )
    print(result)
    result = subprocess.run(
        ["cp", os.path.join("src", "fortran", mech["macro_executable"] + ".f90"), r.os_path],
        cwd=os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis"),
        capture_output=True,
    )
    print(result)
# Out:
# 2024-09-02-1411: TB-xiii__21_105 -- Into and along - External
# CompletedProcess(args=['cp', 'src/fortran/micro_rates.f90', '/home/bpaynter/git/UCO-OpResearch/lysis/data/2024-09-02-1411'], returncode=0, stdout=b'', stderr=b'')
# CompletedProcess(args=['cp', 'src/fortran/macro_diffuse_into_and_along__external.f90', '/home/bpaynter/git/UCO-OpResearch/lysis/data/2024-09-02-1411'], returncode=0, stdout=b'', stderr=b'')

# %%
run = runs[0]
mech = mechanisms[mechanisms["descriptor"] == run["mechanism"]][0]
scen = scenarios[scenarios["descriptor"] == run["scenario"]][0]
r = lysis.util.Run(
    os.path.join(lysis_root, "data"),
    run_code=run["run_code"],
)
r.read_file()
# f = lysis.util.FortranMicro(
#     exp=e,
#     cwd=lysis_root,
#     executable=os.path.join(lysis_root, "bin", mech["micro_executable"]),
#     out_file_code=out_file_code.format(scenario_code=run["scenario"]) + ".dat",
# )
# f.run()
print(r)
# Out:
# {'fibrinogen_length': <Quantity(0.045, 'micron')>, 'fibrinogen_radius': <Quantity(0.0012, 'micron')>, 'fiber_radius': <Quantity(0.0615, 'micron')>, 'diss_const_tPA_wPLG': <Quantity(0.02, 'micromolar')>, 'diss_const_tPA_woPLG': <Quantity(0.36, 'micromolar')>, 'diss_const_PLG_intact': <Quantity(38, 'micromolar')>, 'diss_const_PLG_nicked': <Quantity(2.2, 'micromolar')>, 'bind_rate_tPA': <Quantity(0.1, '1 / micromolar / second')>, 'bind_rate_PLG': <Quantity(0.1, '1 / micromolar / second')>, 'conc_free_PLG': <Quantity(2, 'micromolar')>, 'deg_rate_fibrin': <Quantity(5.0, '1 / second')>, 'unbind_rate_PLi': <Quantity(57.6, '1 / second')>, 'activation_rate_PLG': <Quantity(0.1, '1 / second')>, 'exposure_rate_binding_site': <Quantity(5.0, '1 / second')>, 'nodes_in_micro_row': 13, 'snap_proportion': 0.6666666666666666, 'micro_simulations': 50000, 'micro_seed': 2133256963, 'micro_version': 'micro_rates', 'log_lvl': 30}
# {'pore_size': <Quantity(0.000534, 'centimeter')>, 'diffusion_coeff': <Quantity(5e-07, 'centimeter ** 2 / second')>, 'forced_unbind': 0.074101, 'cols': 19, 'rows': 184, 'empty_rows': 112, 'total_molecules': 21105, 'moving_probability': 0.2, 'macro_simulations': 10, 'total_time': <Quantity(0, 'second')>, 'macro_seed': 3134955532, 'save_interval': <Quantity(10, 'second')>, 'macro_version': 'macro_diffuse_into_and_along__external', 'log_lvl': 30, 'duplicate_fortran': False, 'processing_library': 'numpy', 'micro_params': MicroParameters(fibrinogen_length=<Quantity(0.045, 'micron')>, fibrinogen_radius=<Quantity(0.0012, 'micron')>, fiber_radius=<Quantity(0.0615, 'micron')>, protofibril_radius=<Quantity(0.0024, 'micron')>, diss_const_tPA_wPLG=<Quantity(0.02, 'micromolar')>, diss_const_tPA_woPLG=<Quantity(0.36, 'micromolar')>, diss_const_PLG_intact=<Quantity(38, 'micromolar')>, diss_const_PLG_nicked=<Quantity(2.2, 'micromolar')>, bind_rate_tPA=<Quantity(0.1, '1 / micromolar / second')>, bind_rate_PLG=<Quantity(0.1, '1 / micromolar / second')>, conc_free_PLG=<Quantity(2, 'micromolar')>, deg_rate_fibrin=<Quantity(5.0, '1 / second')>, unbind_rate_PLG_intact=<Quantity(3.8, '1 / second')>, unbind_rate_PLG_nicked=<Quantity(0.22, '1 / second')>, unbind_rate_PLi=<Quantity(57.6, '1 / second')>, unbind_rate_tPA_wPLG=<Quantity(0.002, '1 / second')>, unbind_rate_tPA_woPLG=<Quantity(0.036, '1 / second')>, activation_rate_PLG=<Quantity(0.1, '1 / second')>, exposure_rate_binding_site=<Quantity(5.0, '1 / second')>, protein_per_fiber=<Quantity(25.7370613, 'percent')>, fibrin_conc_per_fiber=<Quantity(1049.67095, 'micromolar')>, binding_sites=<Quantity(298.131395, 'micromolar')>, nodes_in_micro_row=13, snap_proportion=0.6666666666666666, micro_simulations=50000, micro_seed=2133256963, micro_version='micro_rates', log_lvl=30)}
# run_code       : 2024-09-02-1411
# data_filenames : None
# micro_params   : fibrinogen_length          : 0.045 micron
#                  fibrinogen_radius          : 0.0012 micron
#                  fiber_radius               : 0.0615 micron
#                  protofibril_radius         : 0.0024 micron
#                  diss_const_tPA_wPLG        : 0.02 micromolar
#                  diss_const_tPA_woPLG       : 0.36 micromolar
#                  diss_const_PLG_intact      : 38 micromolar
#                  diss_const_PLG_nicked      : 2.2 micromolar
#                  bind_rate_tPA              : 0.1 / micromolar / second
#                  bind_rate_PLG              : 0.1 / micromolar / second
#                  conc_free_PLG              : 2 micromolar
#                  deg_rate_fibrin            : 5.0 / second
#                  unbind_rate_PLG_intact     : 3.8000000000000003 / second
#                  unbind_rate_PLG_nicked     : 0.22000000000000003 / second
#                  unbind_rate_PLi            : 57.6 / second
#                  unbind_rate_tPA_wPLG       : 0.002 / second
#                  unbind_rate_tPA_woPLG      : 0.036 / second
#                  activation_rate_PLG        : 0.1 / second
#                  exposure_rate_binding_site : 5.0 / second
#                  protein_per_fiber          : 25.737061273051754 percent
#                  fibrin_conc_per_fiber      : 1049.670954231157 micromolar
#                  binding_sites              : 298.131395284589 micromolar
#                  nodes_in_micro_row         : 13
#                  snap_proportion            : 0.6666666666666666
#                  micro_simulations          : 50,000
#                  micro_seed                 : 2,133,256,963
#                  micro_version              : micro_rates
#                  log_lvl                    : 30
# macro_params   : pore_size          : 0.000534 centimeter
#                  diffusion_coeff    : 5e-07 centimeter ** 2 / second
#                  forced_unbind      : 0.074101
#                  average_bound_time : 27.77777777777778 second
#                  cols               : 19
#                  rows               : 184
#                  fiber_rows         : 72
#                  empty_rows         : 112
#                  empty_edges        : 6,272
#                  full_row           : 56
#                  xz_row             : 37
#                  total_edges        : 10,285
#                  total_fibers       : 4,013
#                  total_molecules    : 21,105
#                  moving_probability : 0.2
#                  macro_simulations  : 10
#                  total_time         : 0 second
#                  time_step          : 0.0095052 second
#                  total_time_steps   : 0
#                  macro_seed         : 3,134,955,532
#                  state              : (129281, 362436069, 123456789, 3134955532)
#                  input_data         : ['unbinding_time', 'lysis_time_dist', 'total_lyses']
#                  output_data        : ['degradation_state', 'molecule_location', 'molecule_state', 'save_time']
#                  save_interval      : 10 second
#                  number_of_saves    : 1
#                  macro_version      : macro_diffuse_into_and_along__external
#                  log_lvl            : 30
#                  duplicate_fortran  : 0
#                  processing_library : numpy

# %% [markdown]
# ## Microscale

# %%
# For Microscale
folder_vars = """
homedir="/home/bpaynter/git/UCO-OpResearch/lysis"
workdir="/home/bpaynter/tmp/${SLURM_JOB_ID}-${SLURM_ARRAY_TASK_ID}"
datadir="${workdir}/data/${run_code}"
"""

transfer_script = """
# 1. Transfer to node 
# ====================
echo "Starting data transfer to node."

# create/empty the temporary directory on the compute node
if [ ! -d "${workdir}" ]; then
  mkdir -p "${workdir}"
else
  echo rm -ri "${workdir}"/*
fi

mkdir -p "${datadir}"

cp ${homedir}/data/${run_code}/params.json ${datadir}/
cp ${homedir}/bin/${fort_executable} ${workdir}/
echo "Data transfer to node completed."
"""

return_script = """
# 2. Function to transfer back to the head node 
# ==============================================

# define clean-up function
function clean_up {
  # - copy everything from the temporary directory on the compute-node
  echo "Copying data back to home directory."
  mkdir -p ${homedir}/data/${run_code}
  cp -prf "${datadir}"/*${out_code}* ${homedir}/data/${run_code}/
  cp -prf "${datadir}"/*.txt ${homedir}/data/${run_code}/
  # - erase the temporary directory from the compute-node
  echo "Erasing temporary directories."
  rm -rf "${workdir}"/*
  rm -rf "${workdir}"
  # - exit the script
  echo "Job complete. Exiting."
  exit
}

# call "clean_up" function when this script exits, it is run even if SLURM cancels the job
trap 'clean_up' EXIT
"""
execute_script = """
# 3. Execute 
# ===========

source /home/bpaynter/.bashrc
source /home/bpaynter/lysis.sh
cd ${homedir}/src/python
echo "Starting code execution."

python -u fortran_exec.py \
    --out_code ${out_code} \
    --cwd ${workdir} \
    ${workdir}/${fort_executable} \
    ${run_code}
    
sleep 10
echo "Code execution complete."
"""

# %%
for run in runs:
    mech = mechanisms[mechanisms["descriptor"] == run["mechanism"]][0]
    scen = scenarios[scenarios["descriptor"] == run["scenario"]][0]
    r = lysis.util.Run(
        os.path.join(lysis_root, "data"),
        run_code=run["run_code"],
    )
    r.read_file()
    run_vars = f"""
run_code="{r.run_code}"
out_code="{out_file_code.format(scenario_code=run['scenario'])}"
fort_executable="{mech['micro_executable']}"
echo "Run ${{run_code}} Micro (${{out_code}})"
"""
    # job-options
    sbatch = {
        "job-name": f"lysis-micro-{r.run_code}",
        "out": os.path.join(r.os_path, "job.slurm-%A.out"),
        "nodes": 1,
        "mem": 3096,
        "ntasks": 1,
        "cpus-per-task": 1,
        "exclusive=user": "",
        # "exclusive": "",
        # "partition": "long",
    }
    script = [run_vars, folder_vars, transfer_script, return_script, execute_script]
    with open(os.path.join(r.os_path, "job.slurm"), "w") as file:
        file.write(gs.scripts.plain(script, **sbatch))
    result = subprocess.run(
        ["sbatch", os.path.join(r.os_path, "job.slurm")],
        cwd=lysis_root,
        capture_output=True,
    )
    print(result)
# Out:
# CompletedProcess(args=['sbatch', '/home/bpaynter/git/UCO-OpResearch/lysis/data/2024-09-02-1411/job.slurm'], returncode=0, stdout=b'Submitted batch job 3591\n', stderr=b'')

# %% [markdown]
# ## Macroscale

# %%
folder_vars = """
homedir="/home/bpaynter/git/UCO-OpResearch/lysis"
workdir="/home/bpaynter/tmp/${SLURM_ARRAY_JOB_ID}-${SLURM_ARRAY_TASK_ID}"
datadir="${workdir}/data/${run_code}"
"""

transfer_script = """
# 1. Transfer to node 
# ====================
echo "Starting data transfer to node."

# create/empty the temporary directory on the compute node
if [ ! -d "${workdir}" ]; then
  mkdir -p "${workdir}"
else
  echo rm -ri "${workdir}"/*
fi

mkdir -p "${datadir}"

cp ${homedir}/data/${run_code}/*${in_code}.dat ${datadir}/
cp ${homedir}/data/${run_code}/params.json ${datadir}/
cp ${homedir}/bin/${fort_executable} ${workdir}/
echo "Data transfer to node completed."
"""

return_script = """
# 2. Function to transfer back to the head node 
# ==============================================

# define clean-up function
function clean_up {
  sim=$(printf "%02d" ${SLURM_ARRAY_TASK_ID})
  # - copy everything from the temporary directory on the compute-node
  echo "Copying data back to home directory."
  mkdir -p ${homedir}/data/${run_code}/$sim
  cp -prf "${datadir}"/*${out_code}* ${homedir}/data/${run_code}/$sim/
  cp -prf "${datadir}"/*.txt ${homedir}/data/${run_code}/$sim/
  # - erase the temporary directory from the compute-node
  echo "Erasing temporary directories."
  rm -rf "${workdir}"/*
  rm -rf "${workdir}"
  # - exit the script
  echo "Job complete. Exiting."
  exit
}

# call "clean_up" function when this script exits, it is run even if SLURM cancels the job
trap 'clean_up' EXIT
"""
execute_script = """
# 3. Execute 
# ===========

source /home/bpaynter/.bashrc
source /home/bpaynter/lysis.sh
cd ${homedir}/src/python
echo "Starting code execution."

python -u fortran_exec.py \
    --in_code ${in_code} \
    --out_code ${out_code} \
    -n $SLURM_ARRAY_TASK_ID \
    --cwd ${workdir} \
    ${workdir}/${fort_executable} \
    ${run_code}
    
sleep 10
echo "Code execution complete."
"""

# %%
for run in runs:
    mech = mechanisms[mechanisms["descriptor"] == run["mechanism"]][0]
    scen = scenarios[scenarios["descriptor"] == run["scenario"]][0]
    r = lysis.util.Run(
        os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis", "data"),
        run_code=run["run_code"],
    )
    r.read_file()
    run_vars = f"""
run_code="{r.run_code}"
in_code="{in_file_code.format(input_code=run["scenario"].split("_")[0])}"
out_code="{out_file_code.format(scenario_code=run['scenario'])}"
fort_executable="{mech['macro_executable']}"
echo "Experiment ${{run_code}} (${{out_code}}), Simulation #${{SLURM_ARRAY_TASK_ID}}"
"""
    # job-options
    sbatch = {
        "job-name": f"lysis-{r.run_code}",
        "out": os.path.join(r.os_path, "job.slurm-%A-%a.out"),
        "array": f"0-{r.macro_params.macro_simulations-1}",
        "nodes": 1,
        "mem": 3096,
        "ntasks": 1,
        "cpus-per-task": 1,
        "exclusive=user": "",
        # "exclusive": "",
        "partition": "long",
    }
    script = [run_vars, folder_vars, transfer_script, return_script, execute_script]
    with open(os.path.join(r.os_path, "job.slurm"), "w") as file:
        file.write(gs.scripts.plain(script, **sbatch))
    result = subprocess.run(
        ["sbatch", os.path.join(r.os_path, "job.slurm")],
        cwd=os.path.join("/", "home", "bpaynter", "git", "UCO-OpResearch", "lysis"),
        capture_output=True,
    )
    print(result)
# Out:
# {'fibrinogen_length': <Quantity(0.045, 'micron')>, 'fibrinogen_radius': <Quantity(0.0012, 'micron')>, 'fiber_radius': <Quantity(0.0615, 'micron')>, 'diss_const_tPA_wPLG': <Quantity(0.02, 'micromolar')>, 'diss_const_tPA_woPLG': <Quantity(0.36, 'micromolar')>, 'diss_const_PLG_intact': <Quantity(38, 'micromolar')>, 'diss_const_PLG_nicked': <Quantity(2.2, 'micromolar')>, 'bind_rate_tPA': <Quantity(0.1, '1 / micromolar / second')>, 'bind_rate_PLG': <Quantity(0.1, '1 / micromolar / second')>, 'conc_free_PLG': <Quantity(2, 'micromolar')>, 'deg_rate_fibrin': <Quantity(5.0, '1 / second')>, 'unbind_rate_PLi': <Quantity(57.6, '1 / second')>, 'activation_rate_PLG': <Quantity(0.1, '1 / second')>, 'exposure_rate_binding_site': <Quantity(5.0, '1 / second')>, 'nodes_in_micro_row': 13, 'snap_proportion': 0.6666666666666666, 'micro_simulations': 50000, 'micro_seed': 2133256963, 'micro_version': 'micro_rates', 'log_lvl': 30}
# {'pore_size': <Quantity(0.000534, 'centimeter')>, 'diffusion_coeff': <Quantity(5e-07, 'centimeter ** 2 / second')>, 'forced_unbind': 0.074101, 'cols': 19, 'rows': 184, 'empty_rows': 112, 'total_molecules': 21105, 'moving_probability': 0.2, 'macro_simulations': 10, 'total_time': <Quantity(0, 'second')>, 'macro_seed': 3134955532, 'save_interval': <Quantity(10, 'second')>, 'macro_version': 'macro_diffuse_into_and_along__external', 'log_lvl': 30, 'duplicate_fortran': False, 'processing_library': 'numpy', 'micro_params': MicroParameters(fibrinogen_length=<Quantity(0.045, 'micron')>, fibrinogen_radius=<Quantity(0.0012, 'micron')>, fiber_radius=<Quantity(0.0615, 'micron')>, protofibril_radius=<Quantity(0.0024, 'micron')>, diss_const_tPA_wPLG=<Quantity(0.02, 'micromolar')>, diss_const_tPA_woPLG=<Quantity(0.36, 'micromolar')>, diss_const_PLG_intact=<Quantity(38, 'micromolar')>, diss_const_PLG_nicked=<Quantity(2.2, 'micromolar')>, bind_rate_tPA=<Quantity(0.1, '1 / micromolar / second')>, bind_rate_PLG=<Quantity(0.1, '1 / micromolar / second')>, conc_free_PLG=<Quantity(2, 'micromolar')>, deg_rate_fibrin=<Quantity(5.0, '1 / second')>, unbind_rate_PLG_intact=<Quantity(3.8, '1 / second')>, unbind_rate_PLG_nicked=<Quantity(0.22, '1 / second')>, unbind_rate_PLi=<Quantity(57.6, '1 / second')>, unbind_rate_tPA_wPLG=<Quantity(0.002, '1 / second')>, unbind_rate_tPA_woPLG=<Quantity(0.036, '1 / second')>, activation_rate_PLG=<Quantity(0.1, '1 / second')>, exposure_rate_binding_site=<Quantity(5.0, '1 / second')>, protein_per_fiber=<Quantity(25.7370613, 'percent')>, fibrin_conc_per_fiber=<Quantity(1049.67095, 'micromolar')>, binding_sites=<Quantity(298.131395, 'micromolar')>, nodes_in_micro_row=13, snap_proportion=0.6666666666666666, micro_simulations=50000, micro_seed=2133256963, micro_version='micro_rates', log_lvl=30)}
# CompletedProcess(args=['sbatch', '/home/bpaynter/git/UCO-OpResearch/lysis/data/2024-09-02-1411/job.slurm'], returncode=0, stdout=b'Submitted batch job 3740\n', stderr=b'')

# %%
out_file_code
# Out:
# '__hdf5'
